# %%
## Importing Python Script
import sf

# %%
sf.AMT()
# Out:
# [[[[ 0.        ]
#    [ 0.        ]
#    [ 0.        ]
#    ...
#    [        nan]
#    [        nan]
#    [        nan]]
#
#   [[ 0.        ]
#    [ 0.        ]
#    [ 0.        ]
#    ...
#    [        nan]
#    [        nan]
#    [        nan]]
#
#   [[ 0.        ]
#    [ 0.        ]
#    [ 0.        ]
#    ...
#    [        nan]
#    [        nan]
#    [        nan]]
#
#   ...
#
#   [[ 0.        ]
#    [ 0.        ]
#    [ 0.        ]
#    ...
#    [-1.69753456]
#    [-1.69753456]
#    [-1.69753456]]
#
#   [[ 0.        ]
#    [ 0.        ]
#    [ 0.        ]
#    ...
#    [-2.19309497]
#    [-2.19309497]
#    [-2.19309497]]
#
#   [[ 0.        ]
#    [ 0.        ]
#    [ 0.        ]
#    ...
#    [-2.17064905]
#    [-2.17064905]
#    [-2.17064905]]]
#
#
#  [[[ 0.        ]
#    [ 0.        ]
#    [        nan]
#    ...
#    [        nan]
#    [        nan]
#    [        nan]]
#
#   [[ 0.        ]
#    [ 0.        ]
#    [        nan]
#    ...
#    [        nan]
#    [        nan]
# ...

# %%
import imp
imp.reload(sf) # To reload the module

sf.AMT_Framing() # Compute the VQT
# Out:
# C:\Users\Mateu Asus\Documents\YOS4\Lab Project\Code\lab-proj-2020\Digital Signals Processing\sf.py:57: RuntimeWarning: invalid value encountered in true_divide
#   Smels = librosa.display.specshow(mels, sr=fs, x_axis='time', y_axis='mel', fmin=fmin, fmax=8000, cmap="coolwarm")
# (array([[[[ 0.        ],
#           [ 0.        ],
#           [ 0.        ],
#           ...,
#           [        nan],
#           [        nan],
#           [        nan]],
#
#          [[ 0.        ],
#           [ 0.        ],
#           [ 0.        ],
#           ...,
#           [        nan],
#           [        nan],
#           [        nan]],
#
#          [[ 0.        ],
#           [ 0.        ],
#           [ 0.        ],
#           ...,
#           [        nan],
#           [        nan],
#           [        nan]],
#
#          ...,
#
#          [[ 0.        ],
#           [ 0.        ],
#           [ 0.        ],
#           ...,
#           [-1.69753456],
#           [-1.69753456],
# ...
